# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import seaborn as sb

# %%
data = pd.read_csv('matriculasporano2019.csv', sep=';', encoding='utf-8')

# %%
data.plot(x='NU_ANO_CENSO',y='total', style ='o')
plt.xlabel('NU_ANO_CENSO')
plt.ylabel('total')
plt.show()

# %%
X = pd.DataFrame(data['NU_ANO_CENSO'])
y = pd.DataFrame(data['total'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# [45052306.77586207]

# %%
print(regressor.coef_)
# Out:
# [[-20980.78735632]]

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([[2880924.18965517],
#        [2859943.40229885],
#        [2838962.61494253]])

# %%
y_test
# Out:
#      total
# 2  2851500
# 3  2811674
# 4  2793659

# %%
####avaliando o algorítimo

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 40999.068965516984
# Mean Squared Error: 1749378554.0042582

# %%
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test,y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
predictions = regressor.predict(X_test)

# %%
sb.distplot(y_test - predictions, axlabel="Test - Prediction")
# Out:
# <AxesSubplot:xlabel='Test - Prediction', ylabel='Density'>

# %%
myvals = np.array([2020]).reshape(1, -1)
print(regressor.predict(myvals))
# Out:
# [[2671116.31609195]]
